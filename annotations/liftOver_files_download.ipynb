# %% [markdown]
# Download files for liftOver. Can be run on onDemand

# %%
import pandas as pd
from sklearn.neighbors import KNeighborsRegressor
import matplotlib.pyplot as plt
import numpy as np

# %%
# %%bash
#
# curl -L https://zenodo.org/records/7939768/files/gnomad_lofs_with_misannotation_probabilities.tsv.gz?download=1 -o gnomad_lofs_with_misannotation_probabilities.tsv.gz

# %%
misannotation = pd.read_table('gnomad_lofs_with_misannotation_probabilities.tsv.gz')

# %%
misannotation.head()

# %%
misannotation_loci = misannotation[['chr', 'start', 'end', 'locus']].drop_duplicates()
misannotation_loci.chr = 'chr' + misannotation_loci.chr.astype(str)

misannotation_loci.to_csv('misannotation_loci_hg19.bed', sep='\t', header=None, index=None)
del misannotation_loci

# %%
# %%bash
#
# curl http://hgdownload.cse.ucsc.edu/admin/exe/linux.x86_64/liftOver -o liftOver
# chmod u+x liftOver

# %%
# %%bash
# curl https://hgdownload.soe.ucsc.edu/goldenPath/hg19/liftOver/hg19ToHg38.over.chain.gz -o hg19ToHg38.over.chain.gz

# %%
# !gunzip -f hg19ToHg38.over.chain.gz

# %% [markdown]
# ##on terminal <br>
# dx mkdir create_annot <br>
# dx upload misannotation_loci_hg19.bed --path /create_annot/ <br>
# dx upload hg19ToHg38.over.chain --path /create_annot/ <br>
# run liftOver toolkit
